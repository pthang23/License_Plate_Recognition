# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 12919, done.
# remote: Counting objects: 100% (94/94), done.
# remote: Compressing objects: 100% (43/43), done.
# remote: Total 12919 (delta 55), reused 85 (delta 51), pack-reused 12825
# Receiving objects: 100% (12919/12919), 12.36 MiB | 8.92 MiB/s, done.
# Resolving deltas: 100% (8883/8883), done.

# %%
# !cd yolov5
# !pip install -qr /content/yolov5/requirements.txt
# Out:
#      |████████████████████████████████| 596 kB 28.5 MB/s

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# TRAIN OCR
# !python /content/yolov5/train.py --img 640 --batch 32 --epochs 80 --data /gdrive/MyDrive/AIP391/character.yaml --weights yolov5s.pt
# Out:
# train: weights=yolov5s.pt, cfg=, data=/gdrive/MyDrive/AIP391/character.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=80, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=yolov5/runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# remote: Enumerating objects: 60, done.
# remote: Counting objects: 100% (59/59), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 42 (delta 30), reused 25 (delta 16), pack-reused 0
# Unpacking objects: 100% (42/42), done.
# From https://github.com/ultralytics/yolov5
#    38721de..b17629e  master     -> origin/master
# ...

# %%
# DOWNLOAD RESULT TO COMPUTER
from google.colab import files
files.download('/content/yolov5/runs/train/exp/weights/best.pt')
files.download('/content/yolov5/runs/train/exp/results.png')
